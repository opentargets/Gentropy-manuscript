# %% [markdown]
# # Donwload general release data

# %% [markdown]
# Please keep the data in "data" folder localy. Don't commit large data to the repo!

# %%
path_to_release_folder = "gs://open-targets-data-releases/25.06"

# %%
study_index_path = "../../data/study"
credible_set_path = "../../data/credible_set"

# %%
# !gcloud auth login
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=jeEV7VkgXhUCxn9OszEkyc1b8JjfgA&access_type=offline&code_challenge=YgJYPM0IELgqUJHMOJ_UaGzDLiCR8W3YpdOu5cCT5O4&code_challenge_method=S256
#
#
# You are now logged in as [yt4@sanger.ac.uk].
# Your current project is [open-targets-genetics-dev].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID
#
#
# Updates are available for some Google Cloud CLI components.  To install them,
# please run:
# ...

# %%
# !mkdir "$credible_set_path"
# !gsutil -u open-targets-genetics-dev cp \
  -r \
  "$path_to_release_folder/output/study" "$study_index_path"
# Out:
# Copying gs://open-targets-data-releases/25.06/output/study/_SUCCESS...
# Copying gs://open-targets-data-releases/25.06/output/study/part-00000-07bf8025-0ff8-4254-b65e-c2e2662cf4b1-c000.snappy.parquet...
# - [2 files][ 89.0 MiB/ 89.0 MiB]   10.8 MiB/s
# Operation completed over 2 objects/89.0 MiB.

# %%
# !mkdir "$credible_set_path"
# !gsutil -u open-targets-genetics-dev cp \
 -r \
 "$path_to_release_folder/output/credible_set" "$credible_set_path"
# Out:
# Copying gs://open-targets-data-releases/25.06/output/credible_set/_SUCCESS...
# Copying gs://open-targets-data-releases/25.06/output/credible_set/part-00000-33904b03-658b-460b-b4ca-e2facc0a1c98-c000.snappy.parquet...
# Copying gs://open-targets-data-releases/25.06/output/credible_set/part-00001-33904b03-658b-460b-b4ca-e2facc0a1c98-c000.snappy.parquet...
# Copying gs://open-targets-data-releases/25.06/output/credible_set/part-00002-33904b03-658b-460b-b4ca-e2facc0a1c98-c000.snappy.parquet...
# | [4 files][288.7 MiB/288.7 MiB]   14.3 MiB/s
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://open-targets-data-releases/25.06/output/credible_set/part-00003-33904b03-658b-460b-b4ca-e2facc0a1c98-c000.snappy.parquet...
# ...
