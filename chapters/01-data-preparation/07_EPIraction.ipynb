# %% [markdown]
# # EPIraction dataset preparation

# %%
from gentropy import BiosampleIndex, Session, TargetIndex
from gentropy.intervals import IntervalEpiractionStep

# %%
epiraction_path = "../../data/EPIraction"
intervals_path = "../../data/intermediate_files/intervals"
target_path = "../../data/25.06/output/target"
biosample_path = "../../data/25.06/output/biosample"

# %%
session = Session(extended_spark_conf={"spark.driver.memory": "30g"})
epiraction_step = IntervalEpiractionStep(
    session=session,
)
